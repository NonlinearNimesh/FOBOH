# %% [markdown]
# # Data Scrapping
#
# **Objective:**
#     - To automate the scraping of dishes and ingredients from restaurant websites or third-party platforms with minimal manual intervention.
#
# **Thought Process:**
#     - I plan to begin the data scraping process by compiling a comprehensive list of restaurants located in the Sydney CBD 2000 region. Using the names of these establishments, I will leverage SerpAPI to obtain their corresponding websites. Subsequently, I will extract the dishes and their ingredients directly from these websites. This entire workflow is designed to be fully automated, minimizing the need for manual input.

# %% [markdown]
# # Code Flow
# - To gather the names of restaurants, cafes, and pubs in Sydney CBD 2000, I initially considered using popular websites such as Timeout, TripAdvisor, and OpenTable. However, a significant limitation I encountered was that these platforms typically feature only the top-rated establishments. For example, they often present lists like "10 Best Restaurants in Central Business District" or "35 Best Restaurants in Sydney CBD 2000."
#
#
# - To address this issue, I attempted to extract data directly from Google search results, which provided a more comprehensive list of all restaurants in the Sydney CBD 2000 area. Unfortunately, this approach was short-lived due to recurring errors with the ChromeDriver, leading me to revert back to the initial method of sourcing information from curated lists.
#
#
# - After compiling a list of 200 restaurants and successfully retrieving their official websites using the SerpAPI: Google Search API, I now have a comprehensive CSV file containing both the restaurant names and their respective websites. The next step is to extract the dishes offered by these restaurants, along with their corresponding ingredients.

# %%
import requests
from bs4 import BeautifulSoup
import csv

API_KEY = '27f4290fb90ed6306e7f696ac90b83ad6be414615761680819fe0e40a02d3e02'

def get_restaurant_names():
    url = "https://www.timeout.com/sydney/restaurants/the-best-restaurants-in-sydney"
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        restaurant_elements = soup.find_all(['h2', 'h3'])
        restaurant_names = [restaurant.get_text(strip=True) for restaurant in restaurant_elements]
        return restaurant_names
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
        return []

def get_website(restaurant_name):
    params = {
        "q": restaurant_name,
        "location": "Sydney",
        "google_domain": "google.com.au",
        "hl": "en",
        "gl": "au",
        "api_key": API_KEY
    }
    response = requests.get("https://serpapi.com/search.json", params=params)
    if response.status_code == 200:
        results = response.json()
        if 'organic_results' in results and results['organic_results']:
            website = results['organic_results'][0].get('link')
            return website
        else:
            return "No website found"
    else:
        print(f"Failed to fetch results for {restaurant_name}, status code: {response.status_code}")
        return "Failed to retrieve website"

def scrape_menu(website_url):
    try:
        response = requests.get(website_url, timeout=10)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            menu_div = soup.find('div', class_='menu')
            menu_items = []
            if menu_div:
                pdf_link = menu_div.find('a')
                if pdf_link and 'href' in pdf_link.attrs:
                    pdf_url = pdf_link['href']
                    if not pdf_url.startswith('http'):
                        pdf_url = f"{website_url}/{pdf_url}"
                    menu_items.append(pdf_url)
            possible_menu = soup.find_all(string=lambda text: "menu" in text.lower())
            if possible_menu:
                menu_items.extend([menu.get_text(strip=True) for menu in possible_menu])
            return " | ".join(menu_items) if menu_items else "Menu not found"
        else:
            return "Failed to retrieve menu"
    except Exception as e:
        print(f"Error retrieving menu from {website_url}: {str(e)}")
        return "Error"

def save_restaurants_with_menu_to_csv():
    restaurant_names = get_restaurant_names()
    with open('restaurants_with_websites_and_menus.csv', mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['Restaurant Name', 'Website', 'Menu'])
        for name in restaurant_names:
            website = get_website(name)
            print(f"Restaurant: {name}, Website: {website}")
            if "http" in website:
                menu = scrape_menu(website)
            else:
                menu = "Website not found"
            writer.writerow([name, website, menu])

save_restaurants_with_menu_to_csv()

# %% [markdown]
# - The above method gave me ony 200 restraunts name which i think is not enoungh so i tried using llama model to egt the list of restraunts, dish they have in there menu and the ingredients.

# %%
#Llama Extraction code

# %% [markdown]
# # Preprocessing Data
#
# - Load the CSV file (data_updated.csv) with the appropriate encoding (ISO-8859-1) to handle special characters.
# - Define and apply a function to remove leading numbers and periods (e.g., "1. Restaurant Name") from the Restraunts column using a regular expression.
# - Handle missing or non-string values in the dishes and ingridients columns by
#   - Filling any NaN (missing) values with empty strings.
#   - Converting all values in these columns to strings to ensure consistent data types.
# - Group the data by the Restraunts column and merge the dishes and ingridients columns by concatenating unique values for each restaurant.

# %%
import pandas as pd
import re

df = pd.read_csv('data_updated.csv', encoding='ISO-8859-1')
def clean_restaurant_name(name):
    return re.sub(r'^\d+\.\s*', '', name)
df['Restraunts'] = df['Restraunts'].apply(clean_restaurant_name)
df['Dishes'] = df['Dishes'].fillna('').astype(str)
df['Ingridients'] = df['Ingridients'].fillna('').astype(str)
df_merged = df.groupby('Restraunts').agg({
    'Dishes': lambda x: ', '.join(x.unique()),   # Merge unique dishes into a single string
    'Ingridients': lambda x: ', '.join(x.unique()) # Merge unique ingredients into a single string
}).reset_index()
df_merged.to_csv('data_updated_merged.csv', index=False)
print("Merging completed and saved to 'data_updated_merged.csv'.")
# Out:
# Merging completed and saved to 'data_updated_merged.csv'.

# %% [markdown]
# # Handling Aliases
#  - There are three ways to solve this aliases problem.
#    - The manual way
#    - Using fuzzy matching with certain threshold to solve this.
#    - Clustering Similar Ingredients Using Embeddings

# %% [markdown]
# ## The Fuzzy Way

# %%
import pandas as pd

# Load the CSV file into a pandas DataFrame
df = pd.read_csv("data_updated_merged.csv")
df['Ingridients'] = df['Ingridients'].fillna('').astype(str)
# Split the Ingredients column into individual ingredients and create a unique list
all_ingredients = set()
df['Ingridients'].str.split(', ').apply(all_ingredients.update)

# Convert set to a list
all_ingredients = list(all_ingredients)

# %%
print(all_ingredients)
# Out:
# ['burgers', 'Fish', 'variety of baked goods', 'variety of vegetables', '', 'Chutney', 'Premium meats', 'Meat', 'Lamb shoulder', 'noodles', 'Dumplings', 'egg', 'chocolate', 'variety of toppings', 'Ocean Trout', 'Batter', 'cured meats', 'mozzarella cheese', 'croissant pastry', 'Beans', 'Various seafood', 'prawn', 'basil', 'duck', 'trout', 'fine dining ingredients', 'Puff Pastry', 'hoisin sauce', 'Coconut Milk', 'calamari', 'Sake', 'bacon', 'banh mi bread', 'bread', 'olives', 'pastry', 'squid', 'soft shell crab', 'batter', 'Yuca', 'Oysters', 'parmesan cheese', 'raw fish', 'omelette', 'Crab', 'garlic butter', 'halloumi cheese', 'Broccoli', 'blood sausage', 'artichoke', 'Cream', 'Butter', 'soy sauce', 'bun', 'beer batter', 'egg yolk', 'Yogurt', 'spices', 'Pork', 'variety of beans', 'Sandwiches', 'Pasta dishes', 'mixed vegetables', 'Tea', 'fish roe', 'Lentils', 'chili', 'Beef broth', 'seafood mix', 'variety of seafood', 'Mozzarella', 'Premium seafood', 'Snails', 'tomatoes', 'onions', 'variety of wines', 'Bread', 'croutons', 'Pomegranate', 'Mixed tapas dishes', 'Tofu', 'Octopus', 'spanner crab', 'tuna sauce', 'mixers', 'tortillas', 'kidney', 'Beef Tenderloin', 'Thai basil', 'wine selection', 'paneer', 'Fish fillet', 'cream cheese', 'kingfish', 'Fried potatoes', 'Cakes', 'lamb shanks', 'Cornmeal', 'ginger', 'lettuce', 'Snapper', 'Fettuccine', 'pepper', 'quail', 'shallots', 'spicy tomato sauce', 'avocado', 'Argentine-style dishes', 'almond milk', 'Soy Sauce', 'Curry Powder', 'Coffee beans', 'salsa', 'fish', 'preserved lemon', 'snapper', 'mascarpone cheese', 'Potatoes', 'sausage', 'bulgur', 'tahini', 'Grilled meats', 'Peanut', 'proteins', 'small bites', 'charcuterie', 'Paneer', 'breadcrumbs', 'chicken breast', 'Tapas items (meat', 'Saffron', 'hollandaise sauce', 'pizza dough', 'duck leg', 'Ground Beef', 'salt cod', 'Beef patty', 'Coconut', 'shrimp', 'Tacos', 'tartare sauce', 'seasonal dishes', 'Ham', 'Fish Sauce', 'linguine', 'fried balls', 'Wine selection', 'rib-eye steak', 'seeds', 'premium spirits', 'variety of small dishes', 'pasta', 'Onions', 'Rib eye beef', 'garnishes', 'Tahini', 'Wrappers', 'octopus', 'Arborio Rice', 'couscous', 'Corn', 'Flatbread', 'Baked goods', 'Chicken breast', 'Salmon', 'Chianti grapes', 'flour', 'seasoning', 'lamb shoulder', 'lamb', 'ground lamb', 'Kimchi', 'mayonnaise', 'Various international dishes', 'Plantains', 'Rice', 'béchamel', 'arborio rice', 'fish stew', 'sushi rice', 'seafood', 'variety of cheeses', 'Lamb', 'variety of sauces', 'variety of beers', 'fettuccine', 'heirloom vegetables', 'Meats', 'salmon fillet', 'Miso', 'Spinach', 'local brews', 'Cocoa', 'gin', 'barramundi fish', 'burritos', 'Feta Cheese', 'almond flour', 'sugar', 'lemon', 'sourdough bread', 'garlic', 'Bacon', 'chips', 'Duck', 'rosemary', 'fries', 'eggs', 'Pizza dough', 'Dates', 'paella rice', 'mixed meats', 'Mushrooms', 'ingredients vary', 'Sushi rice', 'Noodles', 'mushrooms', 'Chickpeas', 'chicken', 'fish fillet', 'butter', 'vinegar', 'Flour', 'steak', 'red wine', 'spirits', 'Tomato Sauce', 'Couscous', 'Snapper fillet', 'variety', 'lamb mince', 'truffle', 'sauces', 'Parsley', 'variety of spirits', 'potatoes', 'Caramel', 'lime', 'Indian spices', 'parsley', 'romaine lettuce', 'wasabi', 'Avocado', 'olive oil', 'crackers', 'lime leaves', 'Lasagna', 'meats', 'mussels', 'Beef', 'mezcal', 'Honey', 'Seafood mix', 'Barramundi', 'premium meats', 'variety of fillings', 'fillings', 'Spices', 'pork broth', 'beetroot', 'rice', 'hummus', 'feta cheese', 'feta', 'Wagyu Beef', 'Pancakes', 'Thai curries', 'Crepes', 'phyllo pastry', 'Saffron-infused rice', 'Rice noodles', 'vermouth', 'Lamb Shank', 'Taco shells', 'desserts', 'vegetables)', 'tofu', 'Dumpling wrappers', 'king prawns', 'Lemon', 'mozzarella', 'mascarpone', 'variety of ingredients', 'broth', 'Salmon fillet', 'Seafood', 'rice noodles', 'tuna', 'lobster', 'pasta dishes', 'Garlic', 'minced lamb', 'Fruits', 'wrap', 'Vegetables,', 'Spirits', 'Caesar dressing', 'Chocolate', 'Seaweed', 'tomato sau ...

# %%
# !pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# Define a function to find similar ingredients using fuzzy matching
def find_similar_ingredients(ingredient_list, threshold=85):
    similar_ingredients = {}
    
    for i, ingredient in enumerate(ingredient_list):
        # Compare the current ingredient to all others
        matches = process.extract(ingredient, ingredient_list, limit=len(ingredient_list))
        
        # Filter out matches below the threshold
        matches = [match for match in matches if match[1] > threshold and match[0] != ingredient]
        
        if matches:
            # Create a mapping of ingredient -> most similar match
            similar_ingredients[ingredient] = matches[0][0]
    
    return similar_ingredients

# Get a mapping of similar ingredients
similar_ingredient_mapping = find_similar_ingredients(all_ingredients, threshold=85)
print(similar_ingredient_mapping)
# Out:
# C:\Users\NIMESH.KUMAR\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# {'Fish': 'fish', 'variety of baked goods': 'Baked goods', 'variety of vegetables': 'variety', 'Premium meats': 'premium meats', 'Meat': 'meat', 'Lamb shoulder': 'lamb shoulder', 'noodles': 'Noodles', 'egg': 'egg yolk', 'chocolate': 'Chocolate', 'variety of toppings': 'variety', 'Ocean Trout': 'trout', 'Batter': 'batter', 'cured meats': 'Meat', 'mozzarella cheese': 'Mozzarella', 'croissant pastry': 'pastry', 'Beans': 'variety of beans', 'Various seafood': 'seafood', 'prawn': 'prawns', 'basil': 'Basil', 'duck': 'Duck', 'trout': 'Ocean Trout', 'Puff Pastry': 'pastry', 'hoisin sauce': 'Hoisin Sauce', 'Coconut Milk': 'Coconut milk', 'bacon': 'Bacon', 'banh mi bread': 'bread', 'bread': 'Bread', 'pastry': 'Pastry', 'soft shell crab': 'Crab', 'batter': 'Batter', 'Oysters': 'oysters', 'parmesan cheese': 'Cheese', 'raw fish': 'Raw Fish', 'Crab': 'crab', 'garlic butter': 'Butter', 'halloumi cheese': 'Cheese', 'blood sausage': 'sausage', 'Cream': 'cream', 'Butter': 'butter', 'soy sauce': 'Soy Sauce', 'beer batter': 'Batter', 'egg yolk': 'egg', 'spices': 'Spices', 'Pork': 'pork', 'variety of beans': 'Beans', 'Pasta dishes': 'pasta dishes', 'mixed vegetables': 'vegetables)', 'Tea': 'rib-eye steak', 'fish roe': 'Fish', 'chili': 'chili sauce', 'Beef broth': 'Beef', 'seafood mix': 'Seafood mix', 'variety of seafood': 'seafood', 'Mozzarella': 'mozzarella', 'Premium seafood': 'seafood', 'tomatoes': 'Tomatoes', 'onions': 'Onions', 'variety of wines': 'variety', 'Bread': 'bread', 'croutons': 'Croutons', 'Mixed tapas dishes': 'Pasta dishes', 'Tofu': 'tofu', 'Octopus': 'octopus', 'spanner crab': 'Crab', 'tuna sauce': 'tuna', 'tortillas': 'Tortillas', 'Beef Tenderloin': 'Beef', 'Thai basil': 'basil', 'wine selection': 'Wine selection', 'paneer': 'Paneer', 'Fish fillet': 'fish fillet', 'cream cheese': 'Cream', 'kingfish': 'Fish', 'Fried potatoes': 'Potatoes', 'Cakes': 'Pancakes', 'lamb shanks': 'Lamb Shank', 'Cornmeal': 'Corn', 'ginger': 'gin', 'lettuce': 'Lettuce', 'Snapper': 'snapper', 'Fettuccine': 'fettuccine', 'pepper': 'Peppers', 'spicy tomato sauce': 'Tomato Sauce', 'avocado': 'Avocado', 'Argentine-style dishes': 'Pasta dishes', 'almond milk': 'milk', 'Soy Sauce': 'soy sauce', 'Coffee beans': 'coffee beans', 'fish': 'Fish', 'preserved lemon': 'lemon', 'snapper': 'Snapper', 'mascarpone cheese': 'mascarpone', 'Potatoes': 'potatoes', 'sausage': 'sausages', 'tahini': 'Tahini', 'Grilled meats': 'Meat', 'Peanut': 'peanuts', 'small bites': 'variety of small dishes', 'Paneer': 'paneer', 'breadcrumbs': 'bread', 'chicken breast': 'Chicken breast', 'Tapas items (meat': 'tapas items (meat', 'Saffron': 'saffron', 'hollandaise sauce': 'sauce', 'pizza dough': 'Pizza dough', 'duck leg': 'duck', 'Ground Beef': 'Beef', 'salt cod': 'cod', 'Beef patty': 'beef patty', 'Coconut': 'Coconut Milk', 'shrimp': 'Shrimp', 'tartare sauce': 'sauce', 'seasonal dishes': 'variety of small dishes', 'Ham': 'ham', 'Fish Sauce': 'fish sauce', 'Wine selection': 'wine selection', 'rib-eye steak': 'Tea', 'premium spirits': 'spirits', 'variety of small dishes': 'variety of dishes', 'pasta': 'Pasta', 'Onions': 'onions', 'Rib eye beef': 'Beef', 'Tahini': 'tahini', 'Wrappers': 'Dumpling wrappers', 'octopus': 'Octopus', 'Arborio Rice': 'arborio rice', 'couscous': 'Couscous', 'Corn': 'corn', 'Flatbread': 'bread', 'Baked goods': 'variety of baked goods', 'Chicken breast': 'chicken breast', 'Salmon': 'salmon fillet', 'flour': 'Flour', 'lamb shoulder': 'Lamb shoulder', 'lamb': 'Lamb', 'ground lamb': 'lamb', 'mayonnaise': 'Mayonnaise', 'Various international dishes': 'Various seafood', 'Rice': 'rice', 'béchamel': 'Ham', 'arborio rice': 'Arborio Rice', 'fish stew': 'Fish', 'sushi rice': 'Sushi rice', 'seafood': 'Seafood', 'variety of cheeses': 'variety', 'Lamb': 'lamb', 'variety of sauces': 'variety', 'variety of beers': 'variety', 'fettuccine': 'Fettuccine', 'heirloom vegetables': 'vegetables)', 'Meats': 'meats', 'salmon fillet': 'Salmon fillet', 'Miso': 'miso', 'Spinach': 'spinach', 'gin': 'gi ...

# %%
for ingredient, similar in similar_ingredient_mapping.items():
    print(f"{ingredient} -> {similar}")
# Out:
# Fish -> fish
# variety of baked goods -> Baked goods
# variety of vegetables -> variety
# Premium meats -> premium meats
# Meat -> meat
# Lamb shoulder -> lamb shoulder
# noodles -> Noodles
# egg -> egg yolk
# chocolate -> Chocolate
# variety of toppings -> variety
# Ocean Trout -> trout
# Batter -> batter
# cured meats -> Meat
# mozzarella cheese -> Mozzarella
# croissant pastry -> pastry
# Beans -> variety of beans
# Various seafood -> seafood
# prawn -> prawns
# basil -> Basil
# duck -> Duck
# trout -> Ocean Trout
# Puff Pastry -> pastry
# hoisin sauce -> Hoisin Sauce
# Coconut Milk -> Coconut milk
# bacon -> Bacon
# banh mi bread -> bread
# bread -> Bread
# pastry -> Pastry
# soft shell crab -> Crab
# batter -> Batter
# Oysters -> oysters
# parmesan cheese -> Cheese
# raw fish -> Raw Fish
# Crab -> crab
# garlic butter -> Butter
# halloumi cheese -> Cheese
# blood sausage -> sausage
# Cream -> cream
# Butter -> butter
# soy sauce -> Soy Sauce
# beer batter -> Batter
# egg yolk -> egg
# spices -> Spices
# Pork -> pork
# variety of beans -> Beans
# Pasta dishes -> pasta dishes
# mixed vegetables -> vegetables)
# Tea -> rib-eye steak
# fish roe -> Fish
# chili -> chili sauce
# Beef broth -> Beef
# seafood mix -> Seafood mix
# variety of seafood -> seafood
# Mozzarella -> mozzarella
# Premium seafood -> seafood
# tomatoes -> Tomatoes
# onions -> Onions
# variety of wines -> variety
# Bread -> bread
# croutons -> Croutons
# Mixed tapas dishes -> Pasta dishes
# Tofu -> tofu
# Octopus -> octopus
# spanner crab -> Crab
# tuna sauce -> tuna
# tortillas -> Tortillas
# Beef Tenderloin -> Beef
# Thai basil -> basil
# wine selection -> Wine selection
# paneer -> Paneer
# Fish fillet -> fish fillet
# cream cheese -> Cream
# kingfish -> Fish
# Fried potatoes -> Potatoes
# Cakes -> Pancakes
# lamb shanks -> Lamb Shank
# Cornmeal -> Corn
# ginger -> gin
# lettuce -> Lettuce
# Snapper -> snapper
# Fettuccine -> fettuccine
# pepper -> Peppers
# spicy tomato sauce -> Tomato Sauce
# avocado -> Avocado
# Argentine-style dishes -> Pasta dishes
# almond milk -> milk
# Soy Sauce -> soy sauce
# Coffee beans -> coffee beans
# fish -> Fish
# preserved lemon -> lemon
# snapper -> Snapper
# mascarpone cheese -> mascarpone
# Potatoes -> potatoes
# sausage -> sausages
# tahini -> Tahini
# Grilled meats -> Meat
# Peanut -> peanuts
# small bites -> variety of small dishes
# Paneer -> paneer
# breadcrumbs -> bread
# chicken breast -> Chicken breast
# Tapas items (meat -> tapas items (meat
# Saffron -> saffron
# hollandaise sauce -> sauce
# pizza dough -> Pizza dough
# duck leg -> duck
# Ground Beef -> Beef
# salt cod -> cod
# Beef patty -> beef patty
# Coconut -> Coconut Milk
# shrimp -> Shrimp
# tartare sauce -> sauce
# seasonal dishes -> variety of small dishes
# Ham -> ham
# Fish Sauce -> fish sauce
# Wine selection -> wine selection
# rib-eye steak -> Tea
# premium spirits -> spirits
# variety of small dishes -> variety of dishes
# pasta -> Pasta
# Onions -> onions
# Rib eye beef -> Beef
# Tahini -> tahini
# Wrappers -> Dumpling wrappers
# octopus -> Octopus
# Arborio Rice -> arborio rice
# couscous -> Couscous
# Corn -> corn
# Flatbread -> bread
# Baked goods -> variety of baked goods
# Chicken breast -> chicken breast
# Salmon -> salmon fillet
# flour -> Flour
# lamb shoulder -> Lamb shoulder
# lamb -> Lamb
# ground lamb -> lamb
# mayonnaise -> Mayonnaise
# Various international dishes -> Various seafood
# Rice -> rice
# béchamel -> Ham
# arborio rice -> Arborio Rice
# fish stew -> Fish
# sushi rice -> Sushi rice
# seafood -> Seafood
# variety of cheeses -> variety
# Lamb -> lamb
# variety of sauces -> variety
# variety of beers -> variety
# fettuccine -> Fettuccine
# heirloom vegetables -> vegetables)
# Meats -> meats
# salmon fillet -> Salmon fillet
# Miso -> miso
# Spinach -> spinach
# gin -> ginger
# barramundi fish -> Fish
# Feta Cheese -> feta cheese
# almond flour -> flour
# sugar -> Sugar
# lemon -> Lemon
# sourdough bread -> bread
# garlic -> Garlic
# Bacon -> bacon
# Duck -> duck
# eggs -> Eggs
# Pizza dough -> pizza dough
# paella rice -> Rice
# mixed meats -> Meat
# Mushrooms -> mushrooms
# ingredients vary -> stir-fry ingredients (meat
# Sushi rice -> sushi rice
# Noodles -> noodles
# mushrooms -> Mushrooms
# Chickpeas -> chickpeas
# chicken -> Chicken
# fish fillet -> Fish fillet
# butter -> Butter
# Flour -> flour
# steak -> Steak
# red wine -> wine selection
# spirits -> Spirits
# Tomato Sauce -> tomato sauce
# Couscous -> couscous
# Snapper fillet -> Snapper
# variety -> variety of baked goods
# lamb mince -> Lamb mince
# truffle -> truffle oil
# sauces -> sauce
# Parsley -> parsley
# variety of spirits -> spirits
# potatoes -> Potatoes
# lime -> Lime
# Indian spices -> spices
# parsley -> Parsley
# romaine lettuce -> lettuce
# Avocado -> avocado
# olive oil -> Olive Oil
# lime leaves -> lime
# meats -> Meats
# Beef -> beef
# Seafood mix -> seafood mix
# Barramundi -> barramundi fish
# premium meats -> Premium meats
# variety of fillings -> variety
# fillings -> variety of fillings
# Spices -> spices
# pork broth -> Pork
# rice -> Rice
# feta cheese -> Feta Cheese
# feta -> Feta Cheese
# Wagyu Beef -> wagyu beef
# Pancakes -> pancakes
# phyllo pastry -> pastry
# Saffron-infused rice -> saffron-infused rice
# Rice noodles -> rice noodles
# Lamb Shank -> lamb shanks
# Taco shells -> taco shells
# vegetables) -> Vegetables,
# tofu -> Tofu
# Dumpling wrappers -> Wrappers
# king prawns -> prawn
# Lemon -> lemon
# mozzarella -> Mozzarella
# mascarpone -> mascarpone cheese
# variety of ingredients -> variety
# broth -> Broth
# Salmon fillet -> salmon fillet
# Seafood -> seafood
# rice noodles -> Rice noodles
# tuna -> tuna sauce
# pasta dishes -> Pasta dishes
# Garlic -> garlic
# minced lamb -> lamb
# Fruits -> fruit
# wrap -> Wrappers
# Vegetables, -> vegetables)
# Spirits -> spirits
# Chocolate -> chocolate
# Seaweed -> seaweed
# tomato sauce -> Tomato Sauce
# cured ham -> Ham
# crab -> Crab
# Chicken -> chicken
# tomato -> spicy tomato sauce
# Wonton Wrappers -> Wrappers
# Naan Bread -> naan bread
# Rice Noodles -> Rice noodles
# ramen noodles -> noodles
# eggplant -> egg
# mashed potatoes -> Potatoes
# Pastry -> pastry
# pickled ginger -> ginger
# Lamb mince -> lamb mince
# Basil -> basil
# Sushi Rice -> sushi rice
# peanuts -> Peanut
# coffee beans -> Coffee beans
# Cheeses -> cheeses
# Cheese -> cheese
# orange sauce -> sauce
# pancakes -> Pancakes
# Raw Fish -> raw fish
# BBQ sauce -> sauce
# Coffee -> coffee
# Spring Onion -> onion
# goat cheese -> Cheese
# basmati rice -> Rice
# fish sauce -> Fish Sauce
# fruit -> Fruits
# Tahini Sauce -> tahini
# saffron -> Saffron
# wagyu beef -> Wagyu Beef
# toppings -> variety of toppings
# saffron-infused rice -> Saffron-infused rice
# Noodle dishes -> Argentine-style dishes
# beef -> Beef
# Tortillas -> tortillas
# tapas items (meat -> Tapas items (meat
# pita bread -> bread
# cucumber -> Cucumber
# mixed greens -> Mixed tapas dishes
# Tomatoes -> tomatoes
# meat -> Meat
# oysters -> Oysters
# Turkish bread -> bread
# Cucumber -> cucumber
# Beef strips -> beef strips
# Hoisin Sauce -> hoisin sauce
# cream -> Cream
# cheeses -> Cheeses
# scallops -> Scallops
# Pizza Dough -> pizza dough
# chickpeas -> Chickpeas
# duck liver -> duck
# XO sauce -> sauce
# sauce -> sauces
# Japanese-style breakfast dishes -> Pasta dishes
# Chicken broth -> chicken
# Tom -> tomatoes
# grilled chicken skewers -> chicken
# cod -> salt cod
# Shrimp -> shrimp
# Mud Crab -> Crab
# Veggie patty -> egg
# vegetables -> vegetables)
# Scallops -> scallops
# rum -> breadcrumbs
# T-bone steak -> Tea
# grilled tomatoes -> tomatoes
# cheese -> Cheese
# Pasta -> pasta
# Tagine meat -> Meat
# sausages -> sausage
# milk -> Coconut Milk
# Steak -> steak
# taco shells -> Taco shells
# sour cream -> Cream
# Coconut milk -> Coconut Milk
# ham -> Ham
# beef patty -> Beef patty
# spinach -> Spinach
# Tandoori chicken -> chicken
# truffle oil -> truffle
# variety of cured meats and cheeses -> cured meats
# Wagyu beef -> Wagyu Beef
# pizza -> pizza dough
# miso -> Miso
# pork -> Pork
# onion -> onions
# variety of fish -> Fish
# mayo -> mayonnaise
# naan bread -> Naan Bread
# seaweed -> Seaweed
# small dishes -> variety of small dishes
# green beans -> Beans
# variety of meats -> Meat
# focus on seafood -> seafood
# Fried Egg -> egg
# chili sauce -> chili
# stir-fry ingredients (meat -> Meat
# Eggs -> eggs
# Broth -> broth
# Lime -> lime
# beef strips -> Beef strips
# coconut milk -> Coconut Milk
# Mayonnaise -> mayonnaise
# corn -> Corn
# coffee -> Coffee
# Sausage meat -> Meat
# Croutons -> croutons
# prawns -> prawn
# Vegetables -> vegetables)
# Sugar -> sugar
# Olive Oil -> olive oil
# Lettuce -> lettuce
# Pork ribs -> Pork
# variety of dishes -> variety of small dishes
# Peppers -> pepper

# %% [markdown]
# ## Using Embeddings

# %%
# !pip install spacy 
# !pip install nltk
# !pip install scikit-learn
# Out:
# Collecting spacy
#   Using cached spacy-3.8.2-cp39-cp39-win_amd64.whl (12.3 MB)
# Collecting thinc<8.4.0,>=8.3.0
#   Using cached thinc-8.3.2-cp39-cp39-win_amd64.whl (1.5 MB)
# Requirement already satisfied: setuptools in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from spacy) (63.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from spacy) (0.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from spacy) (2.32.3)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.4.1-py3-none-any.whl (182 kB)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from spacy) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from spacy) (2.0.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from spacy) (4.66.5)
# Requirement already satisfied: jinja2 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Collecting weasel<0.5.0,>=0.1.0
#   Using cached weasel-0.4.1-py3-none-any.whl (50 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.9-cp39-cp39-win_amd64.whl (122 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Using cached srsly-2.4.8-cp39-cp39-win_amd64.whl (483 kB)
# Collecting wasabi<1.2.0,>=0.9.1
#   Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.10-cp39-cp39-win_amd64.whl (25 kB)
# Collecting language-data>=1.2
#   Using cached language_data-1.2.0-py3-none-any.whl (5.4 MB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Collecting confection<1.0.0,>=0.0.1
#   Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Collecting blis<1.1.0,>=1.0.0
#   Using cached blis-1.0.1-cp39-cp39-win_amd64.whl (6.4 MB)
# Requirement already satisfied: colorama in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.5)
# Requirement already satisfied: rich>=10.11.0 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.0.4)
# Collecting colorama
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Collecting cloudpathlib<1.0.0,>=0.7.0
#   Using cached cloudpathlib-0.19.0-py3-none-any.whl (49 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)
# Collecting marisa-trie>=0.7.7
#   Using cached marisa_trie-1.2.0-cp39-cp39-win_amd64.whl (152 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Installing collected packages: murmurhash, marisa-trie, colorama, cloudpathlib, catalogue, blis, wasabi, srsly, preshed, language-data, langcodes, confection, weasel, thinc, spacy
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.5
#     Uninstalling colorama-0.4.5:
#       Successfully uninstalled colorama-0.4.5
# Successfully installed blis-1.0.1 catalogue-2.0.10 cloudpathlib-0.19.0 colorama-0.4.6 confection-0.1.5 langcodes-3.4.1 language-data-1.2.0 marisa-trie-1.2.0 murmurhash-1.0.10 preshed-3.0.9 spacy-3.8.2 srsly-2.4.8 thinc-8.3.2 wasabi-1.1.3 weasel-0.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.11.1 requires ruamel-yaml, which is not installed.
# llama-index-core 0.10.68.post1 requires numpy<2.0.0, but you have numpy 2.0.2 which is incompatible.
# chromadb 0.5.5 requires numpy<2.0.0,>=1.22.5, but you have numpy 2.0.2 which is incompatible.
# Requirement already satisfied: nltk in c:\users\nimesh.kumar\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: click in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: tqdm in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: scikit-learn in c:\users\nimesh.kumar\anaconda3\lib\site-packages (1.0.2)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# thinc 8.3.2 requires numpy<2.1.0,>=2.0.0; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
# tensorflow-intel 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.4 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.24.4 which is incompatible.
# blis 1.0.1 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.24.4 which is incompatible.
# Requirement already satisfied: numpy>=1.14.6 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\nimesh.kumar\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Collecting numpy>=1.14.6
#   Downloading numpy-1.24.4-cp39-cp39-win_amd64.whl (14.9 MB)
#      ---------------------------------------- 14.9/14.9 MB 3.1 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# Successfully installed numpy-1.24.4

# %%
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.8.0/en_core_web_md-3.8.0-py3-none-any.whl (33.5 MB)
#      -------------------------------------- 33.5/33.5 MB 305.8 kB/s eta 0:00:00
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.8.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
import pandas as pd
import spacy

# Load spaCy's medium-sized English model
nlp = spacy.load('en_core_web_md')

# Load the CSV file into a pandas DataFrame
df = pd.read_csv("data_updated_merged.csv")
df['Ingridients'] = df['Ingridients'].fillna('').astype(str)

# Split the Ingredients column into individual ingredients
all_ingredients = set()
df['Ingridients'].str.split(', ').apply(all_ingredients.update)

# Convert set to a list
all_ingredients = list(all_ingredients)

# Optional: Remove common stopwords or symbols if necessary
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

def clean_ingredient(ingredient):
    return ' '.join([word for word in ingredient.split() if word.lower() not in stop_words])

all_ingredients = [clean_ingredient(ingredient) for ingredient in all_ingredients]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4656\281822758.py in <module>
#      10 # Split the Ingredients column into individual ingredients
#      11 all_ingredients = set()
# ---> 12 df['Ingridients'].str.split(', ').apply(all_ingredients.update)
#      13
#      14 # Convert set to a list
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: 'float' object is not iterable
